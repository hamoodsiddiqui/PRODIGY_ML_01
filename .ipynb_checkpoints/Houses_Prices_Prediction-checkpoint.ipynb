# %% [markdown]
# # Problem Statement: We have to predict the price of houses by taking square footage, number of bedrooms, and bathrooms.

# %% [markdown]
# ## features we have to take from our dataset
#
# - LotArea
# - BedroomAbvGr
# - BsmtFullBath
# - BsmtHalfBath
# - FullBath
# - HalfBath

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# # Loading Data

# %%
training_data = pd.read_csv("./Data/train.csv")
test_data = pd.read_csv("./Data/test.csv")

# %%
training_data.shape, test_data.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
training_data.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %%
test_data.head(3)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
#
# [3 rows x 80 columns]

# %% [markdown]
# # Data Preprocessing

# %%
training_data = training_data[["LotArea", "BedroomAbvGr", "BsmtFullBath", "BsmtHalfBath", "FullBath", "HalfBath", "SalePrice"]]
test_data = test_data[["Id", "LotArea", "BedroomAbvGr", "BsmtFullBath", "BsmtHalfBath", "FullBath", "HalfBath"]]

# %%
training_data.isnull().sum()
# Out:
# LotArea         0
# BedroomAbvGr    0
# BsmtFullBath    0
# BsmtHalfBath    0
# FullBath        0
# HalfBath        0
# SalePrice       0
# dtype: int64

# %%
training_data.head(3)
# Out:
#    LotArea  BedroomAbvGr  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 0     8450             3             1             0         2         1
# 1     9600             3             0             1         2         0
# 2    11250             3             1             0         2         1
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotArea       1460 non-null   int64
#  1   BedroomAbvGr  1460 non-null   int64
#  2   BsmtFullBath  1460 non-null   int64
#  3   BsmtHalfBath  1460 non-null   int64
#  4   FullBath      1460 non-null   int64
#  5   HalfBath      1460 non-null   int64
#  6   SalePrice     1460 non-null   int64
# dtypes: int64(7)
# memory usage: 80.0 KB

# %% [markdown]
# # Checking correlation of features with Sale Price

# %%
sns.heatmap(training_data.corr(), annot = True)
plt.show()

# %% [markdown]
# # Histograms

# %%
training_data.hist(figsize = (15, 15))
plt.show()

# %%
training_data.boxplot(figsize = (15, 15))
# Out:
# <Axes: >

# %% [markdown]
# # Removing Outliers

# %%
def outlier_remove(df, *args):
    prep_df =df.copy()
    for col in args:
        q3 = prep_df[col].quantile(0.75)
        q1 = prep_df[col].quantile(0.25)
        iqr = q3-q1
        upper_fence = q3 + 1.5 * iqr
        lower_fence = q1 - 1.5 * iqr
        prep_df = prep_df [~((prep_df [col]>upper_fence) | (prep_df [col]<lower_fence))]
    return prep_df

# %%
training_data.shape
# Out:
# (1460, 7)

# %%
training_data = outlier_remove(training_data, "LotArea")

# %%
training_data.shape
# Out:
# (1391, 7)

# %%
training_data
# Out:
#       LotArea  BedroomAbvGr  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 0        8450             3             1             0         2         1
# 1        9600             3             0             1         2         0
# 2       11250             3             1             0         2         1
# 3        9550             3             1             0         1         0
# 4       14260             4             1             0         2         1
# ...       ...           ...           ...           ...       ...       ...
# 1455     7917             3             0             0         2         1
# 1456    13175             3             1             0         2         0
# 1457     9042             4             0             0         2         0
# 1458     9717             2             1             0         1         0
# 1459     9937             3             1             0         1         1
#
#       SalePrice
# 0        208500
# 1        181500
# ...

# %%
training_data.boxplot(figsize = (15, 15))
# Out:
# <Axes: >

# %% [markdown]
# # Splitting Data into training and testing

# %%
X = training_data.drop("SalePrice", axis = 1)
y = training_data["SalePrice"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1251, 6), (1251,), (140, 6), (140,))

# %%
lr_model = LinearRegression()

lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr_model.predict(X_test)

# %%
predictions
# Out:
# array([136970.66236476,  85029.8631062 , 160804.91605353, 148486.17137928,
#        130711.1860364 , 216834.42346023, 184365.61682331, 219349.25075933,
#        256324.63226476, 163887.89865608, 103665.27187496, 177954.95580606,
#        266831.13088873, 161849.26589714, 263753.28648484,  95198.58607198,
#        190756.91275213, 190393.38170907, 220575.18786749, 215780.36888362,
#        138868.26616728, 123442.828603  , 197530.46354814, 142091.01179937,
#        181507.11894663, 108148.53734752, 201538.23022197, 171261.17504301,
#        157541.27274127, 204812.39798632, 190319.35113067, 189808.36976428,
#        181488.5816578 , 162863.43545726, 137882.47068716, 271579.61730989,
#        136361.21821174, 173963.36386123, 185706.66341749, 147604.58676104,
#         76651.39135071, 110315.26917043, 241362.01686995, 172047.5540614 ,
#        243406.84391193, 127245.275275  , 243576.72997517, 149920.61364029,
# ...

# %%
y_test
# Out:
# 1428    119000
# 345     140200
# 1081    133000
# 465     178740
# 145     130000
#          ...
# 761     100000
# 18      159000
# 509     124500
# 1175    285000
# 54      130000
# Name: SalePrice, Length: 140, dtype: int64

# %%
for prediction, actual_value in zip(predictions, y_test):
    print(prediction, actual_value)
# Out:
# 136970.66236475503 119000
# 85029.86310620184 140200
# 160804.91605353108 133000
# 148486.17137928025 178740
# 130711.1860363977 130000
# 216834.4234602305 239000
# 184365.61682331428 151000
# 219349.250759332 199900
# 256324.63226476332 220000
# 163887.8986560805 146000
# 103665.27187496422 173000
# 177954.9558060569 250580
# 266831.13088872633 233230
# 161849.2658971413 106000
# 263753.2864848372 310000
# 95198.5860719817 93000
# 190756.91275213324 140000
# 190393.3817090673 138800
# 220575.18786749037 207000
# 215780.36888362383 270000
# 138868.26616728364 160000
# 123442.82860299583 155000
# 197530.46354814354 200141
# 142091.01179936554 143500
# 181507.1189466328 216837
# 108148.53734751593 110000
# 201538.2302219672 314813
# 171261.17504301431 136900
# 157541.27274127092 181900
# 204812.39798632413 240000
# 190319.3511306708 164500
# 189808.36976428295 180500
# 181488.58165779998 286000
# 162863.43545726413 181000
# 137882.47068716152 113000
# 271579.61730988964 385000
# ...

# %%
r2_score(y_test, predictions) * 100
# Out:
# 48.86262857960787

# %%
mean_squared_error(y_test, predictions)
# Out:
# 2207193262.033101

# %%
f"On average the prediction is {(2207193262.033102) ** (1 / 2)} away"
# Out:
# 'On average the prediction is 46980.77545159405 away'

# %% [markdown]
# # fitting data without splitting

# %%
X = training_data.drop("SalePrice", axis = 1)
y = training_data["SalePrice"]

# %%
lr_model = LinearRegression()

lr_model.fit(X, y)
# Out:
# LinearRegression()

# %%
test_data.isnull().sum()
# Out:
# Id              0
# LotArea         0
# BedroomAbvGr    0
# BsmtFullBath    2
# BsmtHalfBath    2
# FullBath        0
# HalfBath        0
# dtype: int64

# %%
test_data["BsmtFullBath"] = test_data["BsmtFullBath"].fillna(test_data["BsmtFullBath"].mode()[0])
test_data["BsmtHalfBath"] = test_data["BsmtHalfBath"].fillna(test_data["BsmtHalfBath"].mode()[0])

# %%
test_data.isnull().sum()
# Out:
# Id              0
# LotArea         0
# BedroomAbvGr    0
# BsmtFullBath    0
# BsmtHalfBath    0
# FullBath        0
# HalfBath        0
# dtype: int64

# %%
X_test = np.array(test_data.drop("Id", axis = 1))

# %%
predictions = lr_model.predict(X_test)
# Out:
# C:\Users\pc210\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predictions
# Out:
# array([138796.42858826, 178202.14066124, 250644.73164535, ...,
#        208021.45697314, 126449.07152402, 218826.18574199])

# %%
test_data["SalePrice"] = predictions

# %%
test_data
# Out:
#         Id  LotArea  BedroomAbvGr  BsmtFullBath  BsmtHalfBath  FullBath  \
# 0     1461    11622             2           0.0           0.0         1
# 1     1462    14267             3           0.0           0.0         1
# 2     1463    13830             3           0.0           0.0         2
# 3     1464     9978             3           0.0           0.0         2
# 4     1465     5005             2           0.0           0.0         2
# ...    ...      ...           ...           ...           ...       ...
# 1454  2915     1936             3           0.0           0.0         1
# 1455  2916     1894             3           0.0           0.0         1
# 1456  2917    20000             4           1.0           0.0         1
# 1457  2918    10441             3           0.0           1.0         1
# 1458  2919     9627             3           0.0           0.0         2
#
#       HalfBath      SalePrice
# 0            0  138796.428588
# 1            1  178202.140661
# ...

# %%
submission_csv = test_data[["Id", "SalePrice"]]

# %%
submission_csv.to_csv("./house_prediction_submission.csv", index = False)

# %%
loaded_csv = pd.read_csv("./house_prediction_submission.csv")

# %%
loaded_csv
# Out:
#         Id      SalePrice
# 0     1461  138796.428588
# 1     1462  178202.140661
# 2     1463  250644.731645
# 3     1464  221483.409062
# 4     1465  164453.720100
# ...    ...            ...
# 1454  2915   84851.084384
# 1455  2916   84533.126038
# 1456  2917  208021.456973
# 1457  2918  126449.071524
# 1458  2919  218826.185742
#
# [1459 rows x 2 columns]
